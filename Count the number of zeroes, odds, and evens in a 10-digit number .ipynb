# %%
def digits_count(digits):
    """ Takes a list of single digits and returns the 
        count of zeros, evens and odds
    """
    zero = 0
    even= 0
    odd= 0
    for i in digits:
        if i == 0:
            zero += 1
        elif i % 2 == 0:
            even += 1
        else:
            odd += 1
    return zero, even, odd

digit_input = input("Enter a ten-digit number please: ")
digits = [int(i) for i in digit_input] 

zero, even, odd = digits_count(digits)

print('zero: %d' % zero)
print('even: %d' % even)
print('odd: %d' % odd)
# Out:
# Enter a ten-digit number please: 123065498723615404004249785469780
# zero: 5
# even: 15
# odd: 13
